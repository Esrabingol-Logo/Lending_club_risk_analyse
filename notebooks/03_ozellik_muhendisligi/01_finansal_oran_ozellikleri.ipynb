# %%
import sys
sys.path.append('../../')

import logging
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# src/ modüllerinin loglarını görmek için
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s | %(name)s | %(levelname)s | %(message)s'
)

plt.rcParams.update({
    'figure.facecolor': 'white',
    'axes.facecolor'  : 'white',
    'axes.grid'       : False,
    'font.size'       : 11,
})

from src.io.save_artifacts import load_parquet, save_parquet
from src.features.interaction_features import build_features

df = load_parquet('../../data/processed/lending_club_clean.parquet')
print(f"Başlangıç shape: {df.shape}")
