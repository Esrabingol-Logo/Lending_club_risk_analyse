# %%
import sys
sys.path.append('../../')

import pandas as pd
from src.io.save_artifacts import load_parquet
from src.validation.check_schema import check_schema
from src.validation.check_target_values import check_target_values
from src.validation.check_leakage_columns import check_leakage_columns
from src.validation.check_missing_profile import check_missing_profile

# Oluşturulan Parquet'ten oku 
df = load_parquet('../../data/processed/lending_club_raw.parquet')
print(df.shape)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 6
#       4 import pandas as pd
#       5 from src.io.save_artifacts import load_parquet
# ----> 6 from src.validation.check_schema import check_schema
#       7 from src.validation.check_target_values import check_target_values
#       8 from src.validation.check_leakage_columns import check_leakage_columns
#
# ImportError: cannot import name 'check_schema' from 'src.validation.check_schema' (c:\Projects\lending_club_risk\notebooks\01_veri_analizi\../..\src\validation\check_schema.py)
