# %%
import sys
sys.path.append('../../')   # src/ klasörünü bul

from src.io.read_csv_chunks import check_file, count_rows, read_sample, read_full

DATA_PATH = '../../data/raw/accepted_2007_to_2018Q4.csv'

# Dosya var mı?
check_file(DATA_PATH)
# Out:
# ✅ Dosya bulundu: ../../data/raw/accepted_2007_to_2018Q4.csv
#    Boyut: 1597.5 MB
# True

# %%
df = read_sample(DATA_PATH, sample_size=50000)
df.head()
# Out:
# ✅ Dosya bulundu: ../../data/raw/accepted_2007_to_2018Q4.csv
#    Boyut: 1597.5 MB
#
# 🎲 Sample alınıyor... (sample_size=50,000)
# ✅ Sample alındı!
#    Satır  : 50,000
#    Sütun  : 151
#    Süre   : 3.1 saniye
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  65372951        NaN    24000.0      24000.0          24000.0   60 months
# 1  67045454        NaN    35000.0      35000.0          34850.0   36 months
# 2  60954658        NaN    15000.0      15000.0          15000.0   60 months
# 3  60217274        NaN    25000.0      25000.0          25000.0   36 months
# 4  60235854        NaN    10375.0      10375.0          10375.0   36 months
#
#    int_rate  installment grade sub_grade  ... hardship_payoff_balance_amount  \
# 0     11.49       527.71     B        B5  ...                            NaN
# 1     16.99      1247.68     D        D3  ...                            NaN
# ...

# %%
# Tam veriyi oku
df_full = read_full(DATA_PATH)
print(df_full.shape)
# Out:
# ✅ Dosya bulundu: ../../data/raw/accepted_2007_to_2018Q4.csv
#    Boyut: 1597.5 MB
#
# 📂 Dosya okunuyor...
# ✅ Okundu!
#    Satır  : 2,260,701
#    Sütun  : 151
#    Bellek : 3138.4 MB
#    Süre   : 92.7 saniye
# (2260701, 151)
